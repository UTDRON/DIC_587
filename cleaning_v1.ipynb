# %%
import pandas as pd
import numpy as np
import seaborn as sns
from textblob import TextBlob
import json
# %matplotlib inline
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)

# %%
df_movie = pd.read_csv("https://raw.githubusercontent.com/rashida048/Datasets/master/movie_dataset.csv")
# df_movie

# %%
df_movie.describe()
# Out:
#              index        budget             id   popularity       revenue  \
# count  4803.000000  4.803000e+03    4803.000000  4803.000000  4.803000e+03
# mean   2401.000000  2.904504e+07   57165.484281    21.492301  8.226064e+07
# std    1386.651002  4.072239e+07   88694.614033    31.816650  1.628571e+08
# min       0.000000  0.000000e+00       5.000000     0.000000  0.000000e+00
# 25%    1200.500000  7.900000e+05    9014.500000     4.668070  0.000000e+00
# 50%    2401.000000  1.500000e+07   14629.000000    12.921594  1.917000e+07
# 75%    3601.500000  4.000000e+07   58610.500000    28.313505  9.291719e+07
# max    4802.000000  3.800000e+08  459488.000000   875.581305  2.787965e+09
#
#            runtime  vote_average    vote_count
# count  4801.000000   4803.000000   4803.000000
# mean    106.875859      6.092172    690.217989
# std      22.611935      1.194612   1234.585891
# min       0.000000      0.000000      0.000000
# 25%      94.000000      5.600000     54.000000
# 50%     103.000000      6.200000    235.000000
# 75%     118.000000      6.800000    737.000000
# max     338.000000     10.000000  13752.000000

# %% [markdown]
# # Looking at Null Values in the Dataset

# %%
df_movie.isna().sum()
# Out:
# index                      0
# budget                     0
# genres                    28
# homepage                3091
# id                         0
# keywords                 412
# original_language          0
# original_title             0
# overview                   3
# popularity                 0
# production_companies       0
# production_countries       0
# release_date               1
# revenue                    0
# runtime                    2
# spoken_languages           0
# status                     0
# tagline                  844
# title                      0
# vote_average               0
# vote_count                 0
# cast                      43
# crew                       0
# director                  30
# dtype: int64

# %% [markdown]
# # Cleaning Step 3: Treating Null in Overview, Keywords and Homepage column.

# %% [markdown]
# We will omit records that have Null value in Overview and Keywords. But since a huge portion of the dataset has Null Homepage value, we will be omiting the column.

# %% [markdown]
# Examples of data in original 'genres' column

# %%
df_movie.overview.isna().sum()
# Out:
# 3

# %%
df_movie.keywords.isna().sum()
# Out:
# 412

# %%
df_movie.homepage.isna().sum()
# Out:
# 3091

# %%
df_movie = df_movie.drop(columns='keywords', axis =1)

# %%
df_movie = df_movie.drop(columns='homepage', axis =1)
df_movie.head()
# Out:
#    index     budget                                    genres      id  \
# 0      0  237000000  Action Adventure Fantasy Science Fiction   19995
# 1      1  300000000                  Adventure Fantasy Action     285
# 2      2  245000000                    Action Adventure Crime  206647
# 3      3  250000000               Action Crime Drama Thriller   49026
# 4      4  260000000          Action Adventure Science Fiction   49529
#
#                                             keywords original_language  \
# 0  culture clash future space war space colony so...                en
# 1  ocean drug abuse exotic island east india trad...                en
# 2         spy based on novel secret agent sequel mi6                en
# 3  dc comics crime fighter terrorist secret ident...                en
# 4  based on novel mars medallion space travel pri...                en
#
#                              original_title  \
# 0                                    Avatar
# 1  Pirates of the Caribbean: At World's End
# 2                                   Spectre
# 3                     The Dark Knight Rises
# 4                               John Carter
#
#                                             overview  popularity  \
# 0  In the 22nd century, a paraplegic Marine is di...  150.437577
# 1  Captain Barbossa, long believed to be dead, ha...  139.082615
# 2  A cryptic message from Bond’s past sends him o...  107.376788
# 3  Following the death of District Attorney Harve...  112.312950
# 4  John Carter is a war-weary, former military ca...   43.926995
#
#                                 production_companies  \
# 0  [{"name": "Ingenious Film Partners", "id": 289...
# 1  [{"name": "Walt Disney Pictures", "id": 2}, {"...
# 2  [{"name": "Columbia Pictures", "id": 5}, {"nam...
# 3  [{"name": "Legendary Pictures", "id": 923}, {"...
# 4        [{"name": "Walt Disney Pictures", "id": 2}]
#
#                                 production_countries release_date     revenue  \
# 0  [{"iso_3166_1": "US", "name": "United States o...   2009-12-10  2787965087
# 1  [{"iso_3166_1": "US", "name": "United States o...   2007-05-19   961000000
# 2  [{"iso_3166_1": "GB", "name": "United Kingdom"...   2015-10-26   880674609
# 3  [{"iso_3166_1": "US", "name": "United States o...   2012-07-16  1084939099
# 4  [{"iso_3166_1": "US", "name": "United States o...   2012-03-07   284139100
#
#    runtime                                   spoken_languages    status  \
# 0    162.0  [{"iso_639_1": "en", "name": "English"}, {"iso...  Released
# 1    169.0           [{"iso_639_1": "en", "name": "English"}]  Released
# 2    148.0  [{"iso_639_1": "fr", "name": "Fran\u00e7ais"},...  Released
# 3    165.0           [{"iso_639_1": "en", "name": "English"}]  Released
# 4    132.0           [{"iso_639_1": "en", "name": "English"}]  Released
#
#                                           tagline  \
# 0                     Enter the World of Pandora.
# 1  At the end of the world, the adventure begins.
# 2                           A Plan No One Escapes
# 3                                 The Legend Ends
# 4            Lost in our world, found in another.
#
#                                       title  vote_average  vote_count  \
# 0                                    Avatar           7.2       11800
# 1  Pirates of the Caribbean: At World's End           6.9        4500
# 2                                   Spectre           6.3        4466
# 3                     The Dark Knight Rises           7.6        9106
# 4                               John Carter           6.1        2124
#
#                                                 cast  \
# 0  Sam Worthington Zoe Saldana Sigourney Weaver S...
# 1  Johnny Depp Orlando Bloom Keira Knightley Stel...
# 2  Daniel Craig Christoph Waltz L\u00e9a Seydoux ...
# 3  Christian Bale Michael Caine Gary Oldman Anne ...
# 4  Taylor Kitsch Lynn Collins Samantha Morton Wil...
#
#                                                 crew           director
# 0  [{'name': 'Stephen E. Rivkin', 'gender': 0, 'd...      James Cameron
# 1  [{'name': 'Dariusz Wolski', 'gender': 2, 'depa...     Gore Verbinski
# 2  [{'name': 'Thomas Newman', 'gender': 2, 'depar...         Sam Mendes
# 3  [{'name': 'Hans Zimmer', 'gender': 2, 'departm...  Christopher Nolan
# 4  [{'name': 'Andrew Stanton', 'gender': 2, 'depa...     Andrew Stanton

# %% [markdown]
# # Cleaning Step 2: Revenue and Release Status(Post Production and Rumored).

# %% [markdown]
# The feature Revenue mentions the money made by the movie. The status feature consists of three labels Released, Rumored and Post Production. In this cleaning step we wil be dealing whether if revenue is listed for movies that are labeled Rumored or Post Production

# %%
df_movie.status.value_counts()
# Out:
# status
# Released           4384
# Rumored               3
# Post Production       2
# Name: count, dtype: int64

# %%
df_movie.groupby("status").get_group("Rumored").revenue.sum()
# Out:
# 0

# %%
df_movie.groupby("status").get_group("Post Production").revenue.sum()
# Out:
# 841733

# %%
postpd = df_movie.groupby("status").get_group("Post Production")
postpd[postpd["revenue"] > 0].title.unique()
# Out:
# array(['Higher Ground'], dtype=object)

# %%
#Revenue for the Post Produuction was not 0, so we looked at the movie that had revenue more than 0 and checked if the movie has been released or not and it was released so we changed the status
df_movie.status['Higher Ground'] = "Released"
# Out:
# C:\Users\jyoth\AppData\Local\Temp\ipykernel_25652\3898853620.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_movie.status['Higher Ground'] = "Released"

# %% [markdown]
# # Cleaning Step 3: Removing orginal_title column and keeping Translate title column.

# %%
df_movie = df_movie.drop(columns='original_title', axis =1)
df_movie.head()
# Out:
#    index     budget                                    genres      id  \
# 0      0  237000000  Action Adventure Fantasy Science Fiction   19995
# 1      1  300000000                  Adventure Fantasy Action     285
# 2      2  245000000                    Action Adventure Crime  206647
# 3      3  250000000               Action Crime Drama Thriller   49026
# 4      4  260000000          Action Adventure Science Fiction   49529
#
#                                             keywords original_language  \
# 0  culture clash future space war space colony so...                en
# 1  ocean drug abuse exotic island east india trad...                en
# 2         spy based on novel secret agent sequel mi6                en
# 3  dc comics crime fighter terrorist secret ident...                en
# 4  based on novel mars medallion space travel pri...                en
#
#                                             overview  popularity  \
# 0  In the 22nd century, a paraplegic Marine is di...  150.437577
# 1  Captain Barbossa, long believed to be dead, ha...  139.082615
# 2  A cryptic message from Bond’s past sends him o...  107.376788
# 3  Following the death of District Attorney Harve...  112.312950
# 4  John Carter is a war-weary, former military ca...   43.926995
#
#                                 production_companies  \
# 0  [{"name": "Ingenious Film Partners", "id": 289...
# 1  [{"name": "Walt Disney Pictures", "id": 2}, {"...
# 2  [{"name": "Columbia Pictures", "id": 5}, {"nam...
# 3  [{"name": "Legendary Pictures", "id": 923}, {"...
# 4        [{"name": "Walt Disney Pictures", "id": 2}]
#
#                                 production_countries release_date     revenue  \
# 0  [{"iso_3166_1": "US", "name": "United States o...   2009-12-10  2787965087
# 1  [{"iso_3166_1": "US", "name": "United States o...   2007-05-19   961000000
# 2  [{"iso_3166_1": "GB", "name": "United Kingdom"...   2015-10-26   880674609
# 3  [{"iso_3166_1": "US", "name": "United States o...   2012-07-16  1084939099
# 4  [{"iso_3166_1": "US", "name": "United States o...   2012-03-07   284139100
#
#    runtime                                   spoken_languages    status  \
# 0    162.0  [{"iso_639_1": "en", "name": "English"}, {"iso...  Released
# 1    169.0           [{"iso_639_1": "en", "name": "English"}]  Released
# 2    148.0  [{"iso_639_1": "fr", "name": "Fran\u00e7ais"},...  Released
# 3    165.0           [{"iso_639_1": "en", "name": "English"}]  Released
# 4    132.0           [{"iso_639_1": "en", "name": "English"}]  Released
#
#                                           tagline  \
# 0                     Enter the World of Pandora.
# 1  At the end of the world, the adventure begins.
# 2                           A Plan No One Escapes
# 3                                 The Legend Ends
# 4            Lost in our world, found in another.
#
#                                       title  vote_average  vote_count  \
# 0                                    Avatar           7.2       11800
# 1  Pirates of the Caribbean: At World's End           6.9        4500
# 2                                   Spectre           6.3        4466
# 3                     The Dark Knight Rises           7.6        9106
# 4                               John Carter           6.1        2124
#
#                                                 cast  \
# 0  Sam Worthington Zoe Saldana Sigourney Weaver S...
# 1  Johnny Depp Orlando Bloom Keira Knightley Stel...
# 2  Daniel Craig Christoph Waltz L\u00e9a Seydoux ...
# 3  Christian Bale Michael Caine Gary Oldman Anne ...
# 4  Taylor Kitsch Lynn Collins Samantha Morton Wil...
#
#                                                 crew           director
# 0  [{'name': 'Stephen E. Rivkin', 'gender': 0, 'd...      James Cameron
# 1  [{'name': 'Dariusz Wolski', 'gender': 2, 'depa...     Gore Verbinski
# 2  [{'name': 'Thomas Newman', 'gender': 2, 'depar...         Sam Mendes
# 3  [{'name': 'Hans Zimmer', 'gender': 2, 'departm...  Christopher Nolan
# 4  [{'name': 'Andrew Stanton', 'gender': 2, 'depa...     Andrew Stanton

# %% [markdown]
# # Cleaning Step 4: Revenue of Released Movies

# %%
#not done yet
released = df_movie.groupby("status").get_group("Released")

# %%
released_Budget_Zero = released[released.revenue == 0]
released_Budget_Zero.head()
# Out:
#      index     budget                                 genres     id  \
# 135    135  150000000                  Drama Horror Thriller   7978
# 265    265          0                  Comedy Fantasy Family  10588
# 309    309   84000000        Fantasy Comedy Family Adventure  10214
# 376    376   90000000  Science Fiction Action Drama Thriller  10357
# 406    406          0          Drama Animation Family Comedy  51052
#
#                                               keywords original_language  \
# 135  father son relationship victorian england rema...                en
# 265  cat brother sister relationship boredom chaos ...                en
# 309                                   baby mask viking                en
# 376      subway lava volcano volcanologist los angeles                en
# 406  holiday santa claus duringcreditsstinger woman...                en
#
#                                               overview  popularity  \
# 135  Lawrence Talbot, an American man on a visit to...   21.214571
# 265  Conrad and Sally Walden are home alone with th...   18.251129
# 309  Tim Avery, an aspiring cartoonist, finds himse...   17.815595
# 376  An earthquake shatters a peaceful Los Angeles ...   19.836124
# 406  Each Christmas, Santa and his vast army of hig...   19.836830
#
#                                   production_companies  \
# 135  [{"name": "Universal Pictures", "id": 33}, {"n...
# 265  [{"name": "Imagine Entertainment", "id": 23}, ...
# 309  [{"name": "New Line Cinema", "id": 12}, {"name...
# 376  [{"name": "Twentieth Century Fox Film Corporat...
# 406  [{"name": "Columbia Pictures", "id": 5}, {"nam...
#
#                                   production_countries release_date  revenue  \
# 135  [{"iso_3166_1": "US", "name": "United States o...   2010-02-11        0
# 265  [{"iso_3166_1": "US", "name": "United States o...   2003-11-21        0
# 309  [{"iso_3166_1": "DE", "name": "Germany"}, {"is...   2005-02-18        0
# 376  [{"iso_3166_1": "US", "name": "United States o...   1997-04-25        0
# 406  [{"iso_3166_1": "US", "name": "United States o...   2011-02-22        0
#
#      runtime                                   spoken_languages    status  \
# 135    102.0           [{"iso_639_1": "en", "name": "English"}]  Released
# 265     82.0           [{"iso_639_1": "en", "name": "English"}]  Released
# 309     94.0           [{"iso_639_1": "en", "name": "English"}]  Released
# 376    104.0  [{"iso_639_1": "de", "name": "Deutsch"}, {"iso...  Released
# 406     97.0           [{"iso_639_1": "en", "name": "English"}]  Released
#
#                                                tagline               title  \
# 135     When the moon is full the legend comes to life         The Wolfman
# 265                           Don't mess with the hat.  The Cat in the Hat
# 309                                        Who's next?     Son of the Mask
# 376                                 The coast is toast             Volcano
# 406  Ever wonder how 2 Billion presents get deliver...    Arthur Christmas
#
#      vote_average  vote_count  \
# 135           5.5         549
# 265           4.9         366
# 309           3.6         338
# 376           5.2         376
# 406           6.7         333
#
#                                                   cast  \
# 135  Benicio del Toro Anthony Hopkins Emily Blunt H...
# 265  Mike Myers Dakota Fanning Spencer Breslin Kell...
# 309  Jamie Kennedy Alan Cumming Traylor Howard Kal ...
# 376  Tommy Lee Jones Anne Heche Gaby Hoffmann Don C...
# 406  James McAvoy Hugh Laurie Bill Nighy Jim Broadb...
#
#                                                   crew           director
# 135  [{'name': 'Walter Murch', 'gender': 2, 'depart...       Joe Johnston
# 265  [{'name': 'Eric McLeod', 'gender': 2, 'departm...           Bo Welch
# 309  [{'name': 'Greg Gardiner', 'gender': 2, 'depar...  Lawrence Guterman
# 376  [{'name': 'Alan Silvestri', 'gender': 2, 'depa...       Mick Jackson
# 406  [{'name': 'Harry Gregson-Williams', 'gender': ...         Barry Cook

# %%
released_Budget_NZero = released[released.budget != 0]
released_Budget_NZero.head()
# Out:
#    index     budget                                    genres      id  \
# 0      0  237000000  Action Adventure Fantasy Science Fiction   19995
# 1      1  300000000                  Adventure Fantasy Action     285
# 2      2  245000000                    Action Adventure Crime  206647
# 3      3  250000000               Action Crime Drama Thriller   49026
# 4      4  260000000          Action Adventure Science Fiction   49529
#
#                                             keywords original_language  \
# 0  culture clash future space war space colony so...                en
# 1  ocean drug abuse exotic island east india trad...                en
# 2         spy based on novel secret agent sequel mi6                en
# 3  dc comics crime fighter terrorist secret ident...                en
# 4  based on novel mars medallion space travel pri...                en
#
#                                             overview  popularity  \
# 0  In the 22nd century, a paraplegic Marine is di...  150.437577
# 1  Captain Barbossa, long believed to be dead, ha...  139.082615
# 2  A cryptic message from Bond’s past sends him o...  107.376788
# 3  Following the death of District Attorney Harve...  112.312950
# 4  John Carter is a war-weary, former military ca...   43.926995
#
#                                 production_companies  \
# 0  [{"name": "Ingenious Film Partners", "id": 289...
# 1  [{"name": "Walt Disney Pictures", "id": 2}, {"...
# 2  [{"name": "Columbia Pictures", "id": 5}, {"nam...
# 3  [{"name": "Legendary Pictures", "id": 923}, {"...
# 4        [{"name": "Walt Disney Pictures", "id": 2}]
#
#                                 production_countries release_date     revenue  \
# 0  [{"iso_3166_1": "US", "name": "United States o...   2009-12-10  2787965087
# 1  [{"iso_3166_1": "US", "name": "United States o...   2007-05-19   961000000
# 2  [{"iso_3166_1": "GB", "name": "United Kingdom"...   2015-10-26   880674609
# 3  [{"iso_3166_1": "US", "name": "United States o...   2012-07-16  1084939099
# 4  [{"iso_3166_1": "US", "name": "United States o...   2012-03-07   284139100
#
#    runtime                                   spoken_languages    status  \
# 0    162.0  [{"iso_639_1": "en", "name": "English"}, {"iso...  Released
# 1    169.0           [{"iso_639_1": "en", "name": "English"}]  Released
# 2    148.0  [{"iso_639_1": "fr", "name": "Fran\u00e7ais"},...  Released
# 3    165.0           [{"iso_639_1": "en", "name": "English"}]  Released
# 4    132.0           [{"iso_639_1": "en", "name": "English"}]  Released
#
#                                           tagline  \
# 0                     Enter the World of Pandora.
# 1  At the end of the world, the adventure begins.
# 2                           A Plan No One Escapes
# 3                                 The Legend Ends
# 4            Lost in our world, found in another.
#
#                                       title  vote_average  vote_count  \
# 0                                    Avatar           7.2       11800
# 1  Pirates of the Caribbean: At World's End           6.9        4500
# 2                                   Spectre           6.3        4466
# 3                     The Dark Knight Rises           7.6        9106
# 4                               John Carter           6.1        2124
#
#                                                 cast  \
# 0  Sam Worthington Zoe Saldana Sigourney Weaver S...
# 1  Johnny Depp Orlando Bloom Keira Knightley Stel...
# 2  Daniel Craig Christoph Waltz L\u00e9a Seydoux ...
# 3  Christian Bale Michael Caine Gary Oldman Anne ...
# 4  Taylor Kitsch Lynn Collins Samantha Morton Wil...
#
#                                                 crew           director
# 0  [{'name': 'Stephen E. Rivkin', 'gender': 0, 'd...      James Cameron
# 1  [{'name': 'Dariusz Wolski', 'gender': 2, 'depa...     Gore Verbinski
# 2  [{'name': 'Thomas Newman', 'gender': 2, 'depar...         Sam Mendes
# 3  [{'name': 'Hans Zimmer', 'gender': 2, 'departm...  Christopher Nolan
# 4  [{'name': 'Andrew Stanton', 'gender': 2, 'depa...     Andrew Stanton

# %% [markdown]
# # Cleaning Step 5: Overview Sentiment Analysis

# %%
#taken from https://towardsdatascience.com/my-absolute-go-to-for-sentiment-analysis-textblob-3ac3a11d524

def getSubjectivity(text):
   return TextBlob(text).sentiment.subjectivity
  
 #Create a function to get the polarity
def getPolarity(text):
   return TextBlob(text).sentiment.polarity

# %%
subjective = df_movie.overview.apply(getSubjectivity)
sentiment = df_movie.overview.apply(getPolarity)
df_movie["sentiment"] = sentiment
df_movie["subjective"] = subjective

# %%
df_movie.head()
# Out:
#    index     budget                                    genres      id  \
# 0      0  237000000  Action Adventure Fantasy Science Fiction   19995
# 1      1  300000000                  Adventure Fantasy Action     285
# 2      2  245000000                    Action Adventure Crime  206647
# 3      3  250000000               Action Crime Drama Thriller   49026
# 4      4  260000000          Action Adventure Science Fiction   49529
#
#                                             keywords original_language  \
# 0  culture clash future space war space colony so...                en
# 1  ocean drug abuse exotic island east india trad...                en
# 2         spy based on novel secret agent sequel mi6                en
# 3  dc comics crime fighter terrorist secret ident...                en
# 4  based on novel mars medallion space travel pri...                en
#
#                                             overview  popularity  \
# 0  In the 22nd century, a paraplegic Marine is di...  150.437577
# 1  Captain Barbossa, long believed to be dead, ha...  139.082615
# 2  A cryptic message from Bond’s past sends him o...  107.376788
# 3  Following the death of District Attorney Harve...  112.312950
# 4  John Carter is a war-weary, former military ca...   43.926995
#
#                                 production_companies  \
# 0  [{"name": "Ingenious Film Partners", "id": 289...
# 1  [{"name": "Walt Disney Pictures", "id": 2}, {"...
# 2  [{"name": "Columbia Pictures", "id": 5}, {"nam...
# 3  [{"name": "Legendary Pictures", "id": 923}, {"...
# 4        [{"name": "Walt Disney Pictures", "id": 2}]
#
#                                 production_countries release_date     revenue  \
# 0  [{"iso_3166_1": "US", "name": "United States o...   2009-12-10  2787965087
# 1  [{"iso_3166_1": "US", "name": "United States o...   2007-05-19   961000000
# 2  [{"iso_3166_1": "GB", "name": "United Kingdom"...   2015-10-26   880674609
# 3  [{"iso_3166_1": "US", "name": "United States o...   2012-07-16  1084939099
# 4  [{"iso_3166_1": "US", "name": "United States o...   2012-03-07   284139100
#
#    runtime                                   spoken_languages    status  \
# 0    162.0  [{"iso_639_1": "en", "name": "English"}, {"iso...  Released
# 1    169.0           [{"iso_639_1": "en", "name": "English"}]  Released
# 2    148.0  [{"iso_639_1": "fr", "name": "Fran\u00e7ais"},...  Released
# 3    165.0           [{"iso_639_1": "en", "name": "English"}]  Released
# 4    132.0           [{"iso_639_1": "en", "name": "English"}]  Released
#
#                                           tagline  \
# 0                     Enter the World of Pandora.
# 1  At the end of the world, the adventure begins.
# 2                           A Plan No One Escapes
# 3                                 The Legend Ends
# 4            Lost in our world, found in another.
#
#                                       title  vote_average  vote_count  \
# 0                                    Avatar           7.2       11800
# 1  Pirates of the Caribbean: At World's End           6.9        4500
# 2                                   Spectre           6.3        4466
# 3                     The Dark Knight Rises           7.6        9106
# 4                               John Carter           6.1        2124
#
#                                                 cast  \
# 0  Sam Worthington Zoe Saldana Sigourney Weaver S...
# 1  Johnny Depp Orlando Bloom Keira Knightley Stel...
# 2  Daniel Craig Christoph Waltz L\u00e9a Seydoux ...
# 3  Christian Bale Michael Caine Gary Oldman Anne ...
# 4  Taylor Kitsch Lynn Collins Samantha Morton Wil...
#
#                                                 crew           director  \
# 0  [{'name': 'Stephen E. Rivkin', 'gender': 0, 'd...      James Cameron
# 1  [{'name': 'Dariusz Wolski', 'gender': 2, 'depa...     Gore Verbinski
# 2  [{'name': 'Thomas Newman', 'gender': 2, 'depar...         Sam Mendes
# 3  [{'name': 'Hans Zimmer', 'gender': 2, 'departm...  Christopher Nolan
# 4  [{'name': 'Andrew Stanton', 'gender': 2, 'depa...     Andrew Stanton
#
#    sentiment  subjective
# 0   0.041667    0.616667
# 1  -0.083333    0.266667
# 2  -0.306250    0.518750
# 3  -0.044805    0.372078
# 4  -0.016667    0.566667
